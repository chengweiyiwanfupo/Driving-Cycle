m = result[i][0]  # 运动学片段开始点
    n = result[i][1]  # 运动学片段怠速状态结束点
    k = result[i][2]+1  # 运动学片段结束点
    v_average = sum(data_a[m:k,9])/(k-m)#平均速度
    v_average_travel = sum(data_a[n:k,9])/(k-n)#平均行驶速度
    v_max = max(data_a[m:k,9])#最大速度
    #加减速
    plus = []#加速
    slow = []#减速
    uniformity = []#匀速
    for j in range(n+1,k):
        acc = data_a[j][10]#索引10为加速度
        v = data_a[j][9]
        if acc > 0.1:
            plus.append(acc)
        if acc < -0.1:
            slow.append(acc)
        if acc <= 0.1 and acc >= -0.1 and v !=0 :
            uniformity.append(acc)
    # 平均加速度
    if len(plus)==0:
        plus_average =0
    else:
        plus_average = sum(plus)/len(plus)
    # 平均减速度
    if len(slow)==0:
        slow_average =0
    else:
        slow_average = sum(slow)/len(slow)
    #slow_average = sum(slow)/len(slow)
    # 速度标准差
    v_std = np.std(data_a[m:k,9])
    # 加速度标准差
    plus_std = np.std(plus)
    # 减速度标准差
    slow_std = np.std(slow)
    # 运动学片段时长
    time = k - m
    # 怠速时间
    time_0 = n - m+1
    # 加速时间
    time_1 = len(plus)
    # 减速时间
    time_2 = len(slow)
    # 匀速时间
    time_3 = len(uniformity)
    # 怠速时间比
    ratio_0 = time_0/time
    # 加速时间比
    ratio_1 = time_1 / time
    # 减速时间比
    ratio_2 = time_2 / time
    # 匀速时间比
    ratio_3 = time_3 / time
   
    
    all = [v_average,v_average_travel,v_max,plus_average,slow_average,v_std,plus_std,slow_std,time,time_0,time_1,time_2,time_3,ratio_0,ratio_1,ratio_2,ratio_3]
    feature.append(all)

print("开始写入表格")
from pandas.core.frame import DataFrame
data=DataFrame(feature)
data.columns=["平均速度","平均行驶速度","最大速度","平均加速度","平均减速度","速度标准差","加速度标准差","减速度标准差","运动学片段时间长度","怠速时间","加速时间","减速时间","匀速时间","怠速时间比","加速时间比","减速时间比","匀速时间比"]  # 设置表头

data.to_excel('特征值二次改进C001354436144.xlsx',index=None)                          
data
# Out:
# 开始计算特征值
# 开始写入表格
#        平均速度    平均行驶速度      最大速度     平均加速度     平均减速度     速度标准差    加速度标准差  \
# 0  0.138889  0.185185  0.555556  0.111111 -0.111111  0.182151  0.000000
# 1  0.416667  0.416667  1.111111  0.201389 -0.263889  0.386234  0.077018
# 2  0.539683  0.539683  1.388889  0.166667 -0.218056  0.370559  0.078567
#
#      减速度标准差  运动学片段时间长度  怠速时间  加速时间  减速时间  匀速时间     怠速时间比     加速时间比     减速时间比  \
# 0  0.000000         20     6     1     1     8  0.300000  0.050000  0.050000
# 1  0.094540         18     1     4     6     6  0.055556  0.222222  0.333333
# 2  0.049359         35     1     3     8    20  0.028571  0.085714  0.228571
#
#       匀速时间比
# 0  0.400000
# 1  0.333333
# 2  0.571429

# %%
[0.833333333333333, 1.04166666666667, 1.25]

# %%
print("开始计算特征值")
feature = []
#计算特征值
for i in range(len(result)):
    m = result[i][0]  # 运动学片段开始点
    n = result[i][1]  # 运动学片段怠速状态结束点
    k = result[i][2]+1  # 运动学片段结束点
    v_average = sum(data_a[m:k,9])/(k-m)#平均速度
    v_average_travel = sum(data_a[n:k,9])/(k-n)#平均行驶速度
    v_max = max(data_a[m:k,9])#最大速度
    #加减速
    plus = []#加速
    slow = []#减速
    uniformity = []#匀速
    for j in range(m,k):
        acc = data_a[j][10]#索引10为加速度
        if acc > 0:
            plus.append(acc)
        if acc < 0:
            slow.append(acc)
        if acc == 0:
            uniformity.append(acc)
    i+=1
# Out:
# 开始计算特征值

# %%
import pandas as pd
import numpy as np
import xlsxwriter as xw

info = pd.read_excel("D:\jupyter notebook 保存文件\运动学片段二次改进21UEE92Q.xlsx")
data1 = pd.DataFrame(info)
result = data1.values

excel = pd.read_excel("D:\\jupyter notebook 保存文件\\预处理21UEE92Q.xlsx")
data2 = pd.DataFrame(excel)
data_a = data2.values  # 变为数组

# %%
i=0
m = result[i][0]  # 运动学片段开始点
n = result[i][1]  # 运动学片段怠速状态结束点
k = result[i][2]+1  # 运动学片段结束点
v_average = sum(data_a[m:k,9])/(k-m)#平均速度
v_average_travel = sum(data_a[n:k,9])/(k-n)#平均行驶速度
v_max = max(data_a[m:k,9])#最大速度
plus = []#加速
slow = []#减速
uniformity = []#匀速
for j in range(n+1,k+1):
    acc = data_a[j][10]#索引10为加速度
    if acc > 0:
        plus.append(acc)
    if acc < 0:
        slow.append(acc)
    if acc == 0:
        uniformity.append(acc)
        
    # 平均加速度
plus_average = sum(plus)/len(plus)
    # 平均减速度
slow_average = sum(slow)/len(slow)
    # 速度标准差
v_std = np.std(data_a[m:k,9])
    # 加速度标准差
plus_std = np.std(plus)
    # 减速度标准差
slow_std = np.std(slow)
    # 运动学片段时长
time = k - m
    # 怠速时间
time_0 = n - m
    # 加速时间
time_1 = len(plus)
    # 减速时间
time_2 = len(slow)
    # 匀速时间
time_3 = len(uniformity)
    # 怠速时间比
ratio_0 = time_0/time
ratio_1 = time_1 / time
    # 减速时间比
ratio_2 = time_2 / time
    # 匀速时间比
ratio_3 = time_3 / time
                       
all = [v_average,v_average_travel,v_max,plus_average,slow_average,v_std,plus_std,slow_std,time,time_0,time_1,time_2,time_3,ratio_0,ratio_1,ratio_2,ratio_3]
all
# Out:
# [0.6216931216931213,
#  1.0879629629629621,
#  3.33333333333333,
#  1.0416666666666676,
#  -0.5456349206349208,
#  0.9219016858043813,
#  0.17010345435994303,
#  0.43356693221055886,
#  21,
#  9,
#  3,
#  7,
#  2,
#  0.42857142857142855,
#  0.14285714285714285,
#  0.3333333333333333,
#  0.09523809523809523]

# %%
plus = []#加速
slow = []#减速
uniformity = []#匀速
for j in range(n+1,k+1):
    acc = data_a[j][10]#索引10为加速度
    if acc > 0:
        plus.append(acc)
    if acc < 0:
        slow.append(acc)
    if acc == 0:
        uniformity.append(acc)

# %%
    # 平均加速度
plus_average = sum(plus)/len(plus)
    # 平均减速度
slow_average = sum(slow)/len(slow)
    # 速度标准差
v_std = np.std(data_a[m:k,9])
    # 加速度标准差
plus_std = np.std(plus)
    # 减速度标准差
slow_std = np.std(slow)
    # 运动学片段时长
time = k - m
    # 怠速时间
time_0 = n - m
    # 加速时间
time_1 = len(plus)
    # 减速时间
time_2 = len(slow)
    # 匀速时间
time_3 = len(uniformity)
    # 怠速时间比
ratio_0 = time_0/time
ratio_1 = time_1 / time
    # 减速时间比
ratio_2 = time_2 / time
    # 匀速时间比
ratio_3 = time_3 / time
                       
all = [v_average,v_average_travel,v_max,plus_average,slow_average,v_std,plus_std,slow_std,time,time_0,time_1,time_2,time_3,ratio_0,ratio_1,ratio_2,ratio_3]
all
# Out:
# [0.6216931216931213,
#  1.0879629629629621,
#  3.33333333333333,
#  1.0416666666666676,
#  -0.49479166666666685,
#  0.9219016858043813,
#  0.17010345435994303,
#  0.4272914747999643,
#  21,
#  9,
#  3,
#  8,
#  10,
#  0.42857142857142855,
#  0.14285714285714285,
#  0.38095238095238093,
#  0.47619047619047616]
