# %%
# 进行KMeans
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd
import xlsxwriter as xw
import warnings
warnings.filterwarnings("ignore")
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import xlsxwriter as xw
import numpy as np
import matplotlib.pyplot as plt


feature1 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0862019110001700.xlsx")#
feature1 = pd.DataFrame(feature1)
feature1 = feature1.values.tolist()

feature2 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进23EYBPWX.xlsx")#
feature2 = pd.DataFrame(feature2)
feature2 = feature2.values.tolist()

feature3 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进274BBX84-3.xlsx")#
feature3 = pd.DataFrame(feature3)
feature3 = feature3.values.tolist()

feature4 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35BAXYM3.xlsx")#
feature4 = pd.DataFrame(feature4)
feature4 = feature4.values.tolist()

feature5 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进27K78E4X.xlsx")#
feature5 = pd.DataFrame(feature5)
feature5 = feature5.values.tolist()

feature6 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进274BBX84-1.xlsx")#
feature6 = pd.DataFrame(feature6)
feature6 = feature6.values.tolist()

feature7 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进274BBX84-2.xlsx")#
feature7 = pd.DataFrame(feature7)
feature7 = feature7.values.tolist()

feature8 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进27KGXS6P.xlsx")#
feature8 = pd.DataFrame(feature8)
feature8 = feature8.values.tolist()

feature10 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK16UNR6.xlsx")#
feature10 = pd.DataFrame(feature10)
feature10 = feature10.values.tolist()

feature11 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290023246981152.xlsx")#
feature11 = pd.DataFrame(feature11)
feature11 = feature11.values.tolist()

feature12 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290028311620048.xlsx")#
feature12 = pd.DataFrame(feature12)
feature12 = feature12.values.tolist()

feature13 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进29FXKYRY-42.xlsx")#
feature13 = pd.DataFrame(feature13)
feature13 = feature13.values.tolist()

feature14 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进29FXKYRY-41.xlsx")#
feature14 = pd.DataFrame(feature14)
feature14 = feature14.values.tolist()

feature15 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进298GRG5P-2.xlsx")#
feature15 = pd.DataFrame(feature15)
feature15 = feature15.values.tolist()

feature16 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进298GRG5P-1.xlsx")#
feature16 = pd.DataFrame(feature16)
feature16 = feature16.values.tolist()

feature19 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK115NEB-1.xlsx")#
feature19 = pd.DataFrame(feature19)
feature19 = feature19.values.tolist()

feature22 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK115NEB-2.xlsx")#
feature22 = pd.DataFrame(feature22)
feature22 = feature22.values.tolist()

feature23 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进383WPB4E-2.xlsx")#
feature23 = pd.DataFrame(feature23)
feature23 = feature23.values.tolist()

feature25 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进C001653475180.xlsx")#
feature25 = pd.DataFrame(feature25)
feature25 = feature25.values.tolist()

feature26 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290024466252880.xlsx")#
feature26 = pd.DataFrame(feature26)
feature26 = feature26.values.tolist()

feature27 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进383WPB4E-1.xlsx")#
feature27 = pd.DataFrame(feature27)
feature27 = feature27.values.tolist()

feature28 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进382G4DSZ.xlsx")#
feature28 = pd.DataFrame(feature28)
feature28 = feature28.values.tolist()

feature29 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进29FXKYRY-2.xlsx")#
feature29 = pd.DataFrame(feature29)
feature29 = feature29.values.tolist()

feature30 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进384VJ44B.xlsx")#
feature30 = pd.DataFrame(feature30)
feature30 = feature30.values.tolist()

feature32 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290023150080120.xlsx")#
feature32 = pd.DataFrame(feature32)
feature32 = feature32.values.tolist()

feature33 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11ULNB-43.xlsx")#
feature33 = pd.DataFrame(feature33)
feature33 = feature33.values.tolist()

feature34 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进29FXKYRY-1.xlsx")#
feature34 = pd.DataFrame(feature34)
feature34 = feature34.values.tolist()

feature35 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1Q8HFP.xlsx")#
feature35 = pd.DataFrame(feature35)
feature35 = feature35.values.tolist()

feature39 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290023855495400.xlsx")#
feature39 = pd.DataFrame(feature39)
feature39 = feature39.values.tolist()

feature40 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进3312KAQL-2.xlsx")#
feature40 = pd.DataFrame(feature40)
feature40 = feature40.values.tolist()

feature41 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0862019110001700.xlsx")#
feature41 = pd.DataFrame(feature41)
feature41 = feature41.values.tolist()

feature44 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进3312KAQL-1.xlsx")#
feature44 = pd.DataFrame(feature44)
feature44 = feature44.values.tolist()

feature45 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK119Q6U-4.xlsx")#
feature45 = pd.DataFrame(feature45)
feature45 = feature45.values.tolist()

feature46 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11M7JJ-44.xlsx")#
feature46 = pd.DataFrame(feature46)
feature46 = feature46.values.tolist()

feature47 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK119Q6U-1.xlsx")#
feature47 = pd.DataFrame(feature47)
feature47 = feature47.values.tolist()

feature48 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进33K8G7A4-1.xlsx")#
feature48 = pd.DataFrame(feature48)
feature48 = feature48.values.tolist()

feature49 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进29FXKYRY-3.xlsx")#
feature49 = pd.DataFrame(feature49)
feature49 = feature49.values.tolist()

feature51 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进33PC7ARR.xlsx")#
feature51 = pd.DataFrame(feature51)
feature51 = feature51.values.tolist()

feature55 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进2667RYMB.xlsx")#
feature55 = pd.DataFrame(feature55)
feature55 = feature55.values.tolist()

feature60 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进27S2H3BB-4.xlsx")#
feature60 = pd.DataFrame(feature60)
feature60 = feature60.values.tolist()

feature61 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进292Z3X4Y-3.xlsx")#
feature61 = pd.DataFrame(feature61)
feature61 = feature61.values.tolist()

feature66 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11M7JJ-43.xlsx")#
feature66 = pd.DataFrame(feature66)
feature66 = feature66.values.tolist()

feature71 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11MRXU-1.xlsx")#
feature71 = pd.DataFrame(feature71)
feature71 = feature71.values.tolist()

feature73 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1KDGBB-1.xlsx")#
feature73 = pd.DataFrame(feature73)
feature73 = feature73.values.tolist()

feature74 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进38CZ7Y48.xlsx")#
feature74 = pd.DataFrame(feature74)
feature74 = feature74.values.tolist()

feature77 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11MRXU-52.xlsx")#
feature77 = pd.DataFrame(feature77)
feature77 = feature77.values.tolist()

feature79 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11ULNB-42.xlsx")#
feature79 = pd.DataFrame(feature79)
feature79 = feature79.values.tolist()

feature80 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35B63TAK.xlsx")#
feature80 = pd.DataFrame(feature80)
feature80 = feature80.values.tolist()

feature81 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1KDGBB-3.xlsx")#
feature81 = pd.DataFrame(feature81)
feature81 = feature81.values.tolist()

feature82 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11MRXU-41.xlsx")#
feature82 = pd.DataFrame(feature82)
feature82 = feature82.values.tolist()

feature84 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1KHNCJ-2.xlsx")#
feature84 = pd.DataFrame(feature84)
feature84 = feature84.values.tolist()

feature87 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11M7JJ-3.xlsx")#
feature87 = pd.DataFrame(feature87)
feature87 = feature87.values.tolist()

feature88 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进32R6BBZA.xlsx")#
feature88 = pd.DataFrame(feature88)
feature88 = feature88.values.tolist()

feature89 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35B8SNQ8.xlsx")#
feature89 = pd.DataFrame(feature89)
feature89 = feature89.values.tolist()

feature92 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1RS1JJ-2.xlsx")#
feature92 = pd.DataFrame(feature92)
feature92 = feature92.values.tolist()

feature94 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11MRXU-3.xlsx")#
feature94 = pd.DataFrame(feature94)
feature94 = feature94.values.tolist()

feature102 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1KDGBB-2.xlsx")#
feature102 = pd.DataFrame(feature102)
feature102 = feature102.values.tolist()

feature103 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进33K8G7A4-3.xlsx")#
feature103 = pd.DataFrame(feature103)
feature103 = feature103.values.tolist()

feature108 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11ULNB-1.xlsx")#
feature108 = pd.DataFrame(feature108)
feature108 = feature108.values.tolist()

feature111 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进38BBGE8P.xlsx")#
feature111 = pd.DataFrame(feature111)
feature111 = feature111.values.tolist()

feature112 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11ULNB-2.xlsx")#
feature112 = pd.DataFrame(feature112)
feature112 = feature112.values.tolist()

feature114 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35BGYX8X-44.xlsx")#
feature114 = pd.DataFrame(feature114)
feature114 = feature114.values.tolist()

feature119 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进BK1RKLX6.xlsx")#
feature119 = pd.DataFrame(feature119)
feature119 = feature119.values.tolist()

feature124 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进38NGR466-2.xlsx")#
feature124 = pd.DataFrame(feature124)
feature124 = feature124.values.tolist()

feature126 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进27S2H3BB-3.xlsx")#
feature126 = pd.DataFrame(feature126)
feature126 = feature126.values.tolist()

feature129 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11M7JJ-2.xlsx")#
feature129 = pd.DataFrame(feature129)
feature129 = feature129.values.tolist()

feature133 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进27S2H3BB-2.xlsx")#
feature133 = pd.DataFrame(feature133)
feature133 = feature133.values.tolist()

feature134 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进374U48AK.xlsx")#
feature134 = pd.DataFrame(feature134)
feature134 = feature134.values.tolist()

feature143 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进27S2H3BB-1.xlsx")#
feature143 = pd.DataFrame(feature143)
feature143 = feature143.values.tolist()

feature145 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35BGYX8X-41.xlsx")#
feature145 = pd.DataFrame(feature145)
feature145 = feature145.values.tolist()

feature148 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进26CJH54X.xlsx")#
feature148 = pd.DataFrame(feature148)
feature148 = feature148.values.tolist()

feature158 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35BGYX8X-42.xlsx")#
feature158 = pd.DataFrame(feature158)
feature158 = feature158.values.tolist()

feature161 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进35BGYX8X-43.xlsx")#
feature161 = pd.DataFrame(feature161)
feature161 = feature161.values.tolist()

feature162 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进33ACYGRY.xlsx")#
feature162 = pd.DataFrame(feature162)
feature162 = feature162.values.tolist()

feature171 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进AK11MRXU-43.xlsx")#
feature171 = pd.DataFrame(feature171)
feature171 = feature171.values.tolist()

feature184 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290029280630432.xlsx")#
feature184 = pd.DataFrame(feature184)
feature184 = feature184.values.tolist()

feature197 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290025930481080.xlsx")#
feature197 = pd.DataFrame(feature197)
feature197 = feature197.values.tolist()

feature202 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290029794436804.xlsx")#
feature202 = pd.DataFrame(feature202)
feature202 = feature202.values.tolist()

feature212 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290026584554800.xlsx")#
feature212 = pd.DataFrame(feature212)
feature212 = feature212.values.tolist()

feature213 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290024574110560.xlsx")#
feature213 = pd.DataFrame(feature213)
feature213 = feature213.values.tolist()

feature214 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290027024330168.xlsx")#
feature214 = pd.DataFrame(feature214)
feature214 = feature214.values.tolist()

feature215 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290026892654320.xlsx")#
feature215 = pd.DataFrame(feature215)
feature215 = feature215.values.tolist()

feature218 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290026644010576.xlsx")#
feature218 = pd.DataFrame(feature218)
feature218 = feature218.values.tolist()

feature222 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290024401260096.xlsx")#
feature222 = pd.DataFrame(feature222)
feature222 = feature222.values.tolist()

feature223 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0200038485656400.xlsx")#
feature223 = pd.DataFrame(feature223)
feature223 = feature223.values.tolist()

feature224 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290027458733360.xlsx")#
feature224 = pd.DataFrame(feature224)
feature224 = feature224.values.tolist()

feature225 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0290024336981728.xlsx")#
feature225 = pd.DataFrame(feature225)
feature225 = feature225.values.tolist()

feature226 = pd.read_excel("D:\jupyter notebook 保存文件\提取的特征值\特征值二次改进0200036084910192.xlsx")#
feature226 = pd.DataFrame(feature226)
feature226 = feature226.values.tolist()

feature = feature1 + feature2 + feature3+ feature4+ feature5+ feature6+ feature7+ feature8+ feature10+ feature11+ feature12+ feature13+ feature14+ feature15+ feature16+feature19+feature22+ feature23+ feature25+ feature26+ feature27+ feature28+ feature29+ feature30+ feature32+ feature33+ feature34+ feature35+ feature39+ feature40+ feature41+ feature44+ feature45+ feature46+ feature47+ feature48+ feature49+ feature51+feature55+feature60+feature61+feature66+feature71+feature73+feature74+feature77+feature79+feature80+feature81+feature82+feature84+feature87+feature88+feature89+feature92+feature94+feature102+feature103+feature108+feature111+ feature112+ feature114+ feature119+ feature124+ feature126+ feature129+ feature133+ feature134+feature143+ feature145+feature148+feature158+feature161+feature162+feature171+feature184+feature197+feature202 + feature212+ feature213+ feature214+ feature215+ feature218+ feature222+ feature223+ feature224+ feature225+ feature226


feature=pd.DataFrame(feature)
#feature=feature.fillna('0')
#feature=feature.values.tolist()

feature
# Out:
#                0          1          2         3         4         5   \
# 0        0.486111   0.648148   1.944444  0.200296 -0.328935  0.637940
# 1        3.434769   4.776476   6.944444  0.323819 -0.440939  2.790460
# 2        7.083333   8.201754  11.666667  0.386831 -0.351852  4.391150
# 3        7.067901   8.369883  15.000000  0.316813 -0.320175  4.949774
# 4        5.544140   8.993827  13.611111  0.330896 -0.444861  5.537179
# ...           ...        ...        ...       ...       ...       ...
# 162854   5.796887  10.615079  15.833333  0.390255 -0.588889  5.913084
# 162855  18.424001  19.434089  25.833333  0.326603 -0.447560  6.111193
# 162856  15.985103  16.314015  22.222222  0.418170 -0.469527  5.901932
# 162857  16.006747  16.316355  21.944444  0.322626 -0.501379  4.899931
# 162858   9.346065   9.346065  13.333333  0.385403 -0.391571  2.562484
#
#               6         7      8     9      10     11     12        13  \
# ...

# %%
# 检测包含NaN值的行
rows_with_nan =feature[feature.isnull().any(axis=1)]
print(rows_with_nan)
# Out:
#               0         1          2         3         4         5         6   \
# 1216    3.835125  4.572650  10.000000  0.000000 -0.454167  3.880700       NaN
# 2612    6.805556  8.695988  13.888889  0.000000 -0.492848  5.741908       NaN
# 3325    1.696860  4.878472  15.833333  0.000000 -1.125926  3.903367       NaN
# 4226    2.010870  3.083333   9.166667  0.682574  0.000000  2.948928  0.371649
# 4243    0.090580  0.160256   0.277778  0.000000 -0.138889  0.120941       NaN
# ...          ...       ...        ...       ...       ...       ...       ...
# 162707  2.550505  2.550505   6.111111  0.485185  0.000000  1.964965  0.220051
# 162711  0.646552  2.205882   2.777778  0.297068  0.000000  1.117411  0.099039
# 162765  1.348291  4.612573  12.222222  0.000000 -1.178627  3.100055       NaN
# 162828  0.972222  2.592593   5.277778  0.396914  0.000000  1.612979  0.117475
# 162833  0.000000  0.000000   0.000000  0.000000 -1.222222  0.000000       NaN
#
# ...

# %%
feature =feature[-(feature.isnull().any(axis=1))]
feature
# Out:
#                0          1          2         3         4         5   \
# 0        0.486111   0.648148   1.944444  0.200296 -0.328935  0.637940
# 1        3.434769   4.776476   6.944444  0.323819 -0.440939  2.790460
# 2        7.083333   8.201754  11.666667  0.386831 -0.351852  4.391150
# 3        7.067901   8.369883  15.000000  0.316813 -0.320175  4.949774
# 4        5.544140   8.993827  13.611111  0.330896 -0.444861  5.537179
# ...           ...        ...        ...       ...       ...       ...
# 162854   5.796887  10.615079  15.833333  0.390255 -0.588889  5.913084
# 162855  18.424001  19.434089  25.833333  0.326603 -0.447560  6.111193
# 162856  15.985103  16.314015  22.222222  0.418170 -0.469527  5.901932
# 162857  16.006747  16.316355  21.944444  0.322626 -0.501379  4.899931
# 162858   9.346065   9.346065  13.333333  0.385403 -0.391571  2.562484
#
#               6         7      8     9      10     11     12        13  \
# ...

# %%
# PCA转换特征
feature = StandardScaler().fit_transform(feature)

#数据标准化：方差为1，均值为0
#不仅计算训练数据的均值和方差，还会基于计算出来的均值和方差来转换训练数据，从而把数据转换成标准的正态分布
#最大似然估计自选超参数
# pca = PCA(n_components=5)
#先创建一个PCA对象，其中参数n_components表示保留的特征数，默认为1。如果设置成‘mle’,那么会自动确定保留的特征数
pca = PCA(n_components='mle')

# 计算K-means聚类，用来训练PCA模型
pca.fit(feature) 

print("贡献率：",pca.explained_variance_ratio_,"新特征数量：",len(pca.explained_variance_ratio_))    # 返回贡献率

#除了这些输入参数外，有两个PCA类的成员值得关注。
#第一个是explained_variance_，它代表降维后的各主成分的方差值。方差值越大，则说明越是重要的主成分。
#第二个是explained_variance_ratio_,它代表降维后的各主成分的方差值占总方差值的比例,这个比例越大,则越是重要的主成分。
#explained_variance_ratio_计算了每个特征方差贡献率，所有总和为1，explained_variance_为方差值，
#通过合理使用这两个参数可以画出方差贡献率图或者方差值图，便于观察PCA降维最佳值。
plt.plot(pca.explained_variance_ratio_,marker = "o")

plt.xticks(custom_xticks)

plt.xlabel('feature')
plt.ylabel('Contribution degree')
plt.show()
new_feature = pca.transform(feature)    # 将数据X转换成降维后的数据，数据类型：ndarray用于存放同类型元素的多维数组
# Out:
# 贡献率： [4.49193374e-01 2.18745904e-01 1.41555631e-01 5.46672264e-02
#  4.20152450e-02 3.66821168e-02 1.70279430e-02 1.38251666e-02
#  8.65459137e-03 7.21728282e-03 4.31931321e-03 4.10454654e-03
#  9.89310808e-04 5.28686264e-04 2.83037081e-04 1.90428819e-04] 新特征数量： 16

# %%
new_feature
# Out:
# array([[-2.81509784e+00,  2.47581948e-01,  4.03104928e-02, ...,
#          3.57889130e-02,  5.09529232e-03,  1.44338947e-01],
#        [-7.09434949e-01, -3.65027541e-01,  7.74803848e-01, ...,
#          1.33410490e-02,  2.62948140e-02, -2.34305834e-02],
#        [ 3.35564370e-01,  4.08232168e-01,  1.06286789e-01, ...,
#          6.44625358e-02, -8.60311567e-03,  1.05552846e-02],
#        ...,
#        [ 4.13212192e+00,  6.85487671e-01, -5.77632018e-01, ...,
#          8.11475232e-02,  1.94830090e-02, -1.71544940e-03],
#        [ 5.29759328e+00,  2.63512118e+00,  6.31468038e-01, ...,
#         -1.99098873e-01,  8.06369541e-02, -6.85022239e-03],
#        [ 1.22994829e+00,  9.16302931e-02, -1.53551800e+00, ...,
#         -7.89501147e-02,  1.28391719e-01,  2.59698428e-03]])

# %%
new_feature = new_feature[:,0:4]  # 新构建的特征
# KMeans聚类
#分3类，
model = KMeans(n_clusters=3,random_state=100)# random_state随机生成簇中心的状态条件，随机数种子, random_state=234
model.fit(new_feature)    # fit()计算K-means聚类
model_ = model.predict(new_feature)  #将new_feature放到已经训练好的模型中，可以得到预测出的输出值
centroids = model.cluster_centers_     # 获取聚类中心
label_pred = model.labels_           # 获取聚类标签（共有多少种类别）
# inertia = kk.inertia_             # 获取聚类准则的总和（感觉一般没啥用）
#print(centroids)#输出3个类的聚类中心
print(label_pred)

#画聚类的结果
fig, ax = plt.subplots(dpi=300)
scatter = ax.scatter(new_feature[:, 0], new_feature[:, 1],alpha=.6, c=model_ [:])
#legend = ax.legend(*scatter.legend_elements(), loc="upperright", title="Classes") # plt.figure()
plt.title('Kmeans聚类结果')
plt.savefig('Kmeans聚类结果.png')
plt.show()
# Out:
# [1 1 2 ... 2 0 2]

# %%
new_feature = new_feature[:,0:4]  # 新构建的特征
# KMeans聚类
#分3类，
model = KMeans(n_clusters=5,random_state=100)# random_state随机生成簇中心的状态条件，随机数种子, random_state=234
model.fit(new_feature)    # fit()计算K-means聚类
model_ = model.predict(new_feature)  #将new_feature放到已经训练好的模型中，可以得到预测出的输出值
centroids = model.cluster_centers_     # 获取聚类中心
label_pred = model.labels_           # 获取聚类标签（共有多少种类别）
# inertia = kk.inertia_             # 获取聚类准则的总和（感觉一般没啥用）
#print(centroids)#输出3个类的聚类中心
print(label_pred)

#画聚类的结果
fig, ax = plt.subplots(dpi=300)
scatter = ax.scatter(new_feature[:, 0], new_feature[:, 1],alpha=.6, c=model_ [:])
#legend = ax.legend(*scatter.legend_elements(), loc="upperright", title="Classes") # plt.figure()
plt.title('Kmeans聚类结果')
plt.savefig('Kmeans聚类结果.png')
plt.show()

'''#评价聚类


dataframe = pd.DataFrame(data=np.random.randint(0, 50, size=(200, 10)))
# 以kmeans聚类方法为例
kmeans_model = KMeans(n_clusters=3, random_state=1).fit(dataframe)
labels = kmeans_model.labels_
# 计算指标'''
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.cluster import KMeans
score = metrics.davies_bouldin_score(new_feature,label_pred)
print(score)
# Out:
# [1 2 2 ... 0 0 0]
# 1.0076018300050493

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(new_feature,label_pred)
print("轮廓系数:", silhouette_avg)
# Out:
# 轮廓系数: 0.37629841812116155

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

X = new_feature[:,0:4]  # 新构建的特征

# 使用K均值算法进行聚类
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# 绘制散点图
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')

# 标记聚类中心
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='x')

# 绘制聚类边界
h = 0.02  # 网格步长
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap='viridis')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 24
#      22 y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
#      23 xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
# ---> 24 Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])
#      25 Z = Z.reshape(xx.shape)
#      26 plt.contourf(xx, yy, Z, alpha=0.3, cmap='viridis')
#
# File D:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1058, in _BaseKMeans.predict(self, X, sample_weight)
#    1036 """Predict the closest cluster each sample in X belongs to.
#    1037
#    1038 In the vector quantization literature, `cluster_centers_` is called
#    (...)
#    1054     Index of the cluster each sample belongs to.
#    1055 """
#    1056 check_is_fitted(self)
# -> 1058 X = self._check_test_data(X)
#    1059 sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# 创建一个示例数据集
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# 使用K均值算法进行聚类
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# 绘制散点图
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')

# 标记聚类中心
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='x')

# 绘制聚类边界
h = 0.02  # 网格步长
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap='viridis')

plt.show()

# %%
# 记录下每个类别包含的样本索引
label_0 = []
label_1 = []
label_2 = []
# 这里面存的都是索引
for i in range(len(model_)):
    if model_[i] == 0:
        label_0.append(i)
    if model_[i] == 1:
        label_1.append(i)
    if model_[i] == 2:
        label_2.append(i)

print("第1类运动学片段的数量：",len(label_0))
print("第2类运动学片段的数量：",len(label_1))
print("第3类运动学片段的数量：",len(label_2))
# Out:
# 第1类运动学片段的数量： 5813
# 第2类运动学片段的数量： 69727
# 第3类运动学片段的数量： 85649

# %%
# 算3类平均时长：计8号为运行时间长度
def count_average_time(label_list):
    aver_t = 0
    count = 0
    max = 0
    for i in range(len(label_list)):
        if feature[label_list[i]][8] > 50:
            aver_t += feature[label_list[i]][8]
            count += 1
        if feature[label_list[i]][8] > max:
            max = feature[label_list[i]][8]
        
    return aver_t/count,max 
aver_t_0,max_0 = count_average_time(label_0)
aver_t_1,max_1 = count_average_time(label_1)
aver_t_2,max_2 = count_average_time(label_2)

print("第1类运动学片段的平均时长：", aver_t_0)
print("第2类运动学片段的平均时长：", aver_t_1)
print("第3类运动学片段的平均时长：", aver_t_2)

print("第1类运动学片段的最大时长：", max_0)
print("第2类运动学片段的最大时长：", max_1)
print("第3类运动学片段的最大时长：", max_2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[110], line 14
#      11             max = feature[label_list[i]][8]
#      13     return aver_t/count,max
# ---> 14 aver_t_0,max_0 = count_average_time(label_0)
#      15 aver_t_1,max_1 = count_average_time(label_1)
#      16 aver_t_2,max_2 = count_average_time(label_2)
#
# Cell In[110], line 13, in count_average_time(label_list)
#      10     if feature[label_list[i]][8] > max:
#      11         max = feature[label_list[i]][8]
# ---> 13 return aver_t/count,max
#
# ZeroDivisionError: division by zero

# %%
print("聚类中心为：",centroids)
# Out:
# 聚类中心为： [[ 1.67496631 -0.76989348 -0.20824191 -0.14794766]
#  [-2.54880654  0.47388299  0.1157874   0.10500049]
#  [ 6.54553248  5.66204135  1.68545063  0.91485522]]

# %%
# 算一算每个片段与中心点的距离平方和
def distance(label,centroids,new_feature,x):
    result = []
    for i in range(len(label)):
        cost = 0
        for j in range(centroids.shape[1]):
            cost += ((new_feature[label[i]][j] - centroids[x][j]) * 10)**2
        aaa = [label[i],cost]   # 记录索引、代价值
        result.append(aaa)
    return result

result_0 = distance(label_0,centroids,new_feature,0)
result_1 = distance(label_1,centroids,new_feature,1)
result_2 = distance(label_2,centroids,new_feature,2)


# 根据价值从小到大排序
def sort_self(result):
    n = len(result)
    for i in range(n-1):
        for j in range(n - i -1):
            if result[j][1] > result[j+1][1]:
                temp = result[j]
                result[j] = result[j+1]
                result[j+1] = temp
    return result
# 只保留误差最小的30个？
sort_0 = np.array(sort_self(result_0))[0:30,:]
sort_1 = np.array(sort_self(result_1))[0:30,:]
sort_2 = np.array(sort_self(result_2))[0:30,:]
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_9164\2231311455.py", line 28, in <module>
#     sort_0 = np.array(sort_self(result_0))[0:30,:]
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_9164\2231311455.py", line -1, in sort_self
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "D:\anaconda\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
# ...

# %%
print("开始随机组合")
def select_fragment(feature,sort_0,sort_1,sort_2):
    result = []
    for i in range(30):
        for j in range(30):
            for m in range(30):
                
                all_time = feature[int(sort_0[i][0])][8] + feature[int(sort_1[j][0])][8] + feature[int(sort_2[m][0])][8]
                if 1200 <=all_time<= 1800:
                    lalala = [i,j,m]
                    result.append(lalala)
    return result
condition_curve2 = select_fragment(feature,sort_0,sort_1,sort_2)
print(condition_curve2)
